# %%
import pandas as pd
import numpy as np
path=r"C:\Users\aditi\Downloads\E Commerce Dataset.csv"
df=pd.read_csv(path)
df
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     NaN                Phone         1
# 2          50003      1     NaN                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# ...

# %%
df=df.drop('CustomerID',axis=1)
df
# Out:
#       Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0         1     4.0         Mobile Phone         3              6.0
# 1         1     NaN                Phone         1              8.0
# 2         1     NaN                Phone         1             30.0
# 3         1     0.0                Phone         3             15.0
# 4         1     0.0                Phone         1             12.0
# ...     ...     ...                  ...       ...              ...
# 5625      0    10.0             Computer         1             30.0
# 5626      0    13.0         Mobile Phone         1             13.0
# 5627      0     1.0         Mobile Phone         1             11.0
# 5628      0    23.0             Computer         3              9.0
# 5629      0     8.0         Mobile Phone         1             15.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %%
df['PreferredPaymentMode'].value_counts()
# Out:
# PreferredPaymentMode
# Debit Card          2314
# Credit Card         1501
# E wallet             614
# UPI                  414
# COD                  365
# CC                   273
# Cash on Delivery     149
# Name: count, dtype: int64

# %%
df['PreferredPaymentMode'].value_counts().get('CC',0)
# Out:
# 273

# %%
df['PreferredPaymentMode']=df['PreferredPaymentMode'].replace(['CC','COD'],['Credit Card','Cash on Delivery'])

# %%
df['PreferredPaymentMode'].value_counts()
# Out:
# PreferredPaymentMode
# Debit Card          2314
# Credit Card         1774
# E wallet             614
# Cash on Delivery     514
# UPI                  414
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Churn                        5630 non-null   int64
#  1   Tenure                       5366 non-null   float64
#  2   PreferredLoginDevice         5630 non-null   object
#  3   CityTier                     5630 non-null   int64
#  4   WarehouseToHome              5379 non-null   float64
#  5   PreferredPaymentMode         5630 non-null   object
#  6   Gender                       5630 non-null   object
#  7   HourSpendOnApp               5375 non-null   float64
#  8   NumberOfDeviceRegistered     5630 non-null   int64
#  9   PreferedOrderCat             5630 non-null   object
#  10  SatisfactionScore            5630 non-null   int64
#  11  MaritalStatus                5630 non-null   object
#  12  NumberOfAddress              5630 non-null   int64
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
col=['PreferredLoginDevice','PreferredPaymentMode','Gender','PreferedOrderCat','MaritalStatus']
for i in col:
    df[i]=le.fit_transform(df[i])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
col = ['PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus']

label_mappings = {}

for i in col:
    df[i] = le.fit_transform(df[i])  # Encoding column
    label_mappings[i] = dict(zip(le.classes_, le.transform(le.classes_)))  # Storing mapping

# Print mappings
for col_name, mapping in label_mappings.items():
    print(f"Mapping for {col_name}: {mapping}")
# Out:
# Mapping for PreferredLoginDevice: {'Computer': 0, 'Mobile Phone': 1, 'Phone': 2}
# Mapping for PreferredPaymentMode: {'Cash on Delivery': 0, 'Credit Card': 1, 'Debit Card': 2, 'E wallet': 3, 'UPI': 4}
# Mapping for Gender: {'Female': 0, 'Male': 1}
# Mapping for PreferedOrderCat: {'Fashion': 0, 'Grocery': 1, 'Laptop & Accessory': 2, 'Mobile': 3, 'Mobile Phone': 4, 'Others': 5}
# Mapping for MaritalStatus: {'Divorced': 0, 'Married': 1, 'Single': 2}

# %%
df
# Out:
#       Churn  Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0         1     4.0                     1         3              6.0
# 1         1     NaN                     2         1              8.0
# 2         1     NaN                     2         1             30.0
# 3         1     0.0                     2         3             15.0
# 4         1     0.0                     2         1             12.0
# ...     ...     ...                   ...       ...              ...
# 5625      0    10.0                     0         1             30.0
# 5626      0    13.0                     1         1             13.0
# 5627      0     1.0                     1         1             11.0
# 5628      0    23.0                     0         3              9.0
# 5629      0     8.0                     1         1             15.0
#
#       PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %% [markdown]
# # Handling duplicates

# %%
df.duplicated().sum()
# Out:
# 556

# %%
df=df.drop_duplicates()

# %% [markdown]
# # Handling missing values

# %%
df.isnull().sum()
# Out:
# Churn                            0
# Tenure                         231
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                221
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 230
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    252
# CouponUsed                     210
# OrderCount                     243
# DaySinceLastOrder              288
# CashbackAmount                   0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer(n_neighbors=5)
df_imp=imputer.fit_transform(df)
df=pd.DataFrame(df_imp,columns=df.columns)
df
# Out:
#       Churn  Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       1.0     4.0                   1.0       3.0              6.0
# 1       1.0    10.2                   2.0       1.0              8.0
# 2       1.0     8.4                   2.0       1.0             30.0
# 3       1.0     0.0                   2.0       3.0             15.0
# 4       1.0     0.0                   2.0       1.0             12.0
# ...     ...     ...                   ...       ...              ...
# 5069    0.0     5.0                   0.0       1.0             12.0
# 5070    0.0     1.0                   1.0       3.0             12.0
# 5071    0.0    13.0                   1.0       1.0             13.0
# 5072    0.0     1.0                   1.0       1.0             11.0
# 5073    0.0     8.0                   1.0       1.0             15.0
#
#       PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %%
df.isnull().sum()
# Out:
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %% [markdown]
# # Handling Outliers

# %%
import matplotlib.pyplot as mp
import seaborn as sb

mp.figure(figsize=(10,6))
sb.boxplot(data=df[['Tenure','WarehouseToHome','HourSpendOnApp','NumberOfDeviceRegistered','NumberOfAddress','OrderAmountHikeFromlastYear','CouponUsed','CashbackAmount']])
mp.xticks(rotation=45)
mp.show()

# %% [markdown]
# # Since cashback amount depends on number of purchases, the outliers represent the VIP Customer purchases, so no need to remove

# %% [markdown]
# # Feature Selection

# %%
axis_corr = sb.heatmap(
df.corr(),
vmin=-1, vmax=1, center=0,
cmap=sb.diverging_palette(50, 500, n=500),
square=True
)
mp.show()

# %%
correlation = df.corr()['Churn'].abs().sort_values(ascending=False)
print(correlation)

# Select features with high correlation (e.g., > 0.1)
# selected_features = correlation[correlation > 0.01].index.tolist()
# selected_features.remove('Placement')  # Remove the target variable
# print("Selected Features:", selected_features)
# Out:
# Churn                          1.000000
# Tenure                         0.339502
# Complain                       0.248738
# CashbackAmount                 0.143202
# DaySinceLastOrder              0.139323
# MaritalStatus                  0.137000
# NumberOfDeviceRegistered       0.116788
# PreferedOrderCat               0.104102
# SatisfactionScore              0.100867
# CityTier                       0.098159
# WarehouseToHome                0.068405
# NumberOfAddress                0.052086
# OrderCount                     0.029603
# Gender                         0.029006
# OrderAmountHikeFromlastYear    0.019593
# HourSpendOnApp                 0.009012
# CouponUsed                     0.008619
# PreferredPaymentMode           0.007624
# PreferredLoginDevice           0.004380
# Name: Churn, dtype: float64

# %% [markdown]
# #Dropping below columns as they dont contribute much to churn and not further required

# %%
df=df.drop(['PreferredLoginDevice','PreferredPaymentMode'], axis=1)

# %% [markdown]
# #From the map , it can be seen that order count is highle correlated to features: Cashback amount, Coupon used and Day Since last order..so dropping orfer count

# %%
df=df.drop('OrderCount', axis=1)

# %% [markdown]
# #Not applying pca as want to preserve the features' understanding

# %% [markdown]
# # Balancing Imbalanced dataset

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# 0.0    0.834253
# 1.0    0.165747
# Name: proportion, dtype: float64

# %%
from imblearn import over_sampling
from imblearn.over_sampling import SMOTE


X = df.drop(columns=["Churn"])
y = df["Churn"]


smote = SMOTE(sampling_strategy="auto", random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)


df_resampled = pd.DataFrame(X_resampled, columns=X.columns)
df_resampled["Churn"] = y_resampled

print(df_resampled["Churn"].value_counts())
# Out:
# Churn
# 1.0    4233
# 0.0    4233
# Name: count, dtype: int64

# %%
df_resampled.to_csv('E Commerce dataset_processed.csv')
